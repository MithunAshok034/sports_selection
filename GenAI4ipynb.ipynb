# %% [markdown]
# <a href="https://colab.research.google.com/github/MithunAshok034/sports_selection/blob/main/GenAI4ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 24.1 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)

# %%
from gensim.models import Word2Vec

# %%
# =============================================

from gensim.models import Word2Vec

# ── 1. Reuse the same Medical Corpus ─────────

corpus = [

    "The patient was diagnosed with diabetes and hypertension by doctor.",

    "MRI scans reveal abnormalities in the brain tissue said the doctor.",

    "The treatment by doctor involves antibiotics and regular monitoring.",

    "Symptoms include fever, fatigue, and muscle pain.",

    "The vaccine is effective against several viral infections.",

    "Doctor recommend physical therapy for recovery.",

    "The clinical trial results were published in the journal.",

    "The surgeon performed a minimally invasive procedure.",

    "The prescription by doctor includes pain relievers and anti-inflammatory drugs.",

    "The diagnosis confirmed a rare genetic disorder."

]

# %%
Sentences=[sentence.lower().split() for sentence in corpus ]
print(Sentences)
# Out:
# [['the', 'patient', 'was', 'diagnosed', 'with', 'diabetes', 'and', 'hypertension', 'by', 'doctor.'], ['mri', 'scans', 'reveal', 'abnormalities', 'in', 'the', 'brain', 'tissue', 'said', 'the', 'doctor.'], ['the', 'treatment', 'by', 'doctor', 'involves', 'antibiotics', 'and', 'regular', 'monitoring.'], ['symptoms', 'include', 'fever,', 'fatigue,', 'and', 'muscle', 'pain.'], ['the', 'vaccine', 'is', 'effective', 'against', 'several', 'viral', 'infections.'], ['doctor', 'recommend', 'physical', 'therapy', 'for', 'recovery.'], ['the', 'clinical', 'trial', 'results', 'were', 'published', 'in', 'the', 'journal.'], ['the', 'surgeon', 'performed', 'a', 'minimally', 'invasive', 'procedure.'], ['the', 'prescription', 'by', 'doctor', 'includes', 'pain', 'relievers', 'and', 'anti-inflammatory', 'drugs.'], ['the', 'diagnosis', 'confirmed', 'a', 'rare', 'genetic', 'disorder.']]

# %%
model=Word2Vec(Sentences,vector_size=100,window=5,min_count=1,epochs=50)

# %%
original_prompt="Write a short note on doctor and patient treatment  "

# %%
def similar_words(word):
  if word in model.wv:
    return [w for w,s in model.wv.most_similar(word,topn=3)]
  return []

# %%
doctor_similar=similar_words("doctor")
patient_similar=similar_words("patient")
treatment_similar=similar_words("treatment")

# %%
print("Similar to doctor:", doctor_similar)

print("Similar to patient:", patient_similar)

print("Similar to treatment:", treatment_similar)
# Out:
# Similar to doctor: ['pain.', 'said', 'genetic']
# Similar to patient: ['procedure.', 'hypertension', 'disorder.']
# Similar to treatment: ['diagnosis', 'was', 'physical']

# %%
enrich_prompt=f"""Weite a detail explanation about doctor,{','.join(doctor_similar)},patient,{','.join(patient_similar)},treatment_including{','.join(treatment_similar)}"""

# %%
def response_generator(prompt):
  return f"\n Generate prompt:\n{prompt}"

# %%
original_output=response_generator(original_prompt)
enrich_output=response_generator(enrich_prompt)

# %%
print(original_prompt)
print(enrich_prompt)
print(original_output)
print(enrich_output)
# Out:
# Write a short note on doctor and patient treatment
# Weite a detail explanation about doctor,pain.,said,genetic,patient,procedure.,hypertension,disorder.,treatment_includingdiagnosis,was,physical
#
#  Generate prompt:
# Write a short note on doctor and patient treatment
#
#  Generate prompt:
# Weite a detail explanation about doctor,pain.,said,genetic,patient,procedure.,hypertension,disorder.,treatment_includingdiagnosis,was,physical

# %%
print(len(original_prompt))
print(len(enrich_prompt))
# Out:
# 52
# 142
